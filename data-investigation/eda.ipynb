# %%
import pandas as pd
import seaborn as sns
import os

import sys; sys.path.append('..')

from config import DATASET_CSV_OUTPUT_PATH

# %%
df = pd.read_csv(os.path.join('..', DATASET_CSV_OUTPUT_PATH))

# %%
cm = sns.light_palette("green", as_cmap=True)
df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_eb17e_row0_col1 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_eb17e_row0_col2, #T_eb17e_row1_col10 {
#   background-color: #c9e2c8;
#   color: #000000;
# }
# #T_eb17e_row0_col3 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_eb17e_row0_col4, #T_eb17e_row4_col10 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_eb17e_row0_col5, #T_eb17e_row7_col9 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_eb17e_row0_col6, #T_eb17e_row4_col4 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_eb17e_row0_col7, #T_eb17e_row2_col1, #T_eb17e_row2_col2, #T_eb17e_row2_col4, #T_eb17e_row2_col7, #T_eb17e_row3_col7, #T_eb17e_row4_col6, #T_eb17e_row4_col7, #T_eb17e_row5_col7, #T_eb17e_row6_col2, #T_eb17e_row6_col3, #T_eb17e_row6_col5, #T_eb17e_row6_col8, #T_eb17e_row8_col7, #T_eb17e_row10_col7, #T_eb17e_row11_col9, #T_eb17e_row11_col10 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_eb17e_row0_col8 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_eb17e_row0_col9 {
#   background-color: #81bf81;
#   color: #000000;
# }
# #T_eb17e_row0_col10 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_eb17e_row1_col1, #T_eb17e_row1_col2, #T_eb17e_row1_col3, #T_eb17e_row1_col5, #T_eb17e_row1_col7, #T_eb17e_row2_col9, #T_eb17e_row2_col10, #T_eb17e_row6_col7, #T_eb17e_row7_col6, #T_eb17e_row7_col7, #T_eb17e_row9_col7, #T_eb17e_row10_col4, #T_eb17e_row10_col8, #T_eb17e_row11_col7 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_eb17e_row1_col4 {
#   background-color: #89c389;
#   color: #000000;
# }
# #T_eb17e_row1_col6 {
#   background-color: #90c790;
#   color: #000000;
# }
# #T_eb17e_row1_col8 {
#   background-color: #3f9f3f;
#   color: #f1f1f1;
# }
# #T_eb17e_row1_col9 {
#   background-color: #cfe5cf;
#   color: #000000;
# }
# #T_eb17e_row2_col3, #T_eb17e_row2_col5, #T_eb17e_row2_col8, #T_eb17e_row4_col5 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_eb17e_row2_col6 {
#   background-color: #a0cea0;
#   color: #000000;
# }
# #T_eb17e_row3_col1, #T_eb17e_row5_col1 {
#   background-color: #98ca98;
#   color: #000000;
# }
# #T_eb17e_row3_col2, #T_eb17e_row5_col2, #T_eb17e_row8_col2, #T_eb17e_row10_col3 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_eb17e_row3_col3, #T_eb17e_row5_col3 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_eb17e_row3_col4, #T_eb17e_row5_col4 {
#   background-color: #389b38;
#   color: #f1f1f1;
# }
# #T_eb17e_row3_col5, #T_eb17e_row5_col5, #T_eb17e_row9_col10 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_eb17e_row3_col6, #T_eb17e_row5_col6, #T_eb17e_row8_col9 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_eb17e_row3_col8, #T_eb17e_row4_col1, #T_eb17e_row5_col8 {
#   background-color: #b3d8b3;
#   color: #000000;
# }
# #T_eb17e_row3_col9, #T_eb17e_row5_col9, #T_eb17e_row6_col9 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_eb17e_row3_col10, #T_eb17e_row5_col10 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_eb17e_row4_col2, #T_eb17e_row4_col9, #T_eb17e_row6_col10 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_eb17e_row4_col3, #T_eb17e_row11_col3, #T_eb17e_row11_col5 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_eb17e_row4_col8 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_eb17e_row6_col1 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_eb17e_row6_col4, #T_eb17e_row11_col8 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_eb17e_row6_col6, #T_eb17e_row8_col8 {
#   background-color: #a2cfa2;
#   color: #000000;
# }
# #T_eb17e_row7_col1 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_eb17e_row7_col2 {
#   background-color: #8cc58c;
#   color: #000000;
# }
# #T_eb17e_row7_col3 {
#   background-color: #c0dec0;
#   color: #000000;
# }
# #T_eb17e_row7_col4 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# #T_eb17e_row7_col5 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_eb17e_row7_col8 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_eb17e_row7_col10, #T_eb17e_row9_col5 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_eb17e_row8_col1 {
#   background-color: #77ba77;
#   color: #f1f1f1;
# }
# #T_eb17e_row8_col3, #T_eb17e_row8_col5 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_eb17e_row8_col4 {
#   background-color: #2b952b;
#   color: #f1f1f1;
# }
# #T_eb17e_row8_col6 {
#   background-color: #a1cfa1;
#   color: #000000;
# }
# #T_eb17e_row8_col10 {
#   background-color: #e0eedf;
#   color: #000000;
# }
# #T_eb17e_row9_col1 {
#   background-color: #cae3ca;
#   color: #000000;
# }
# #T_eb17e_row9_col2, #T_eb17e_row9_col3 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_eb17e_row9_col4 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_eb17e_row9_col6 {
#   background-color: #55a955;
#   color: #f1f1f1;
# }
# #T_eb17e_row9_col8 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_eb17e_row9_col9 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_eb17e_row10_col1 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_eb17e_row10_col2 {
#   background-color: #bdddbd;
#   color: #000000;
# }
# #T_eb17e_row10_col5 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_eb17e_row10_col6 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_eb17e_row10_col9 {
#   background-color: #beddbe;
#   color: #000000;
# }
# #T_eb17e_row10_col10, #T_eb17e_row11_col2 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_eb17e_row11_col1 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_eb17e_row11_col4 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_eb17e_row11_col6 {
#   background-color: #84c184;
#   color: #000000;
# }
# </style>
# <table id="T_eb17e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb17e_level0_col0" class="col_heading level0 col0" >project_name </th>
#       <th id="T_eb17e_level0_col1" class="col_heading level0 col1" >num_files </th>
#       <th id="T_eb17e_level0_col2" class="col_heading level0 col2" >num_contracts </th>
#       <th id="T_eb17e_level0_col3" class="col_heading level0 col3" >num_functions </th>
#       <th id="T_eb17e_level0_col4" class="col_heading level0 col4" >num_failures </th>
#       <th id="T_eb17e_level0_col5" class="col_heading level0 col5" >cc_total </th>
#       <th id="T_eb17e_level0_col6" class="col_heading level0 col6" >cc_mean            </th>
#       <th id="T_eb17e_level0_col7" class="col_heading level0 col7" >cc_median </th>
#       <th id="T_eb17e_level0_col8" class="col_heading level0 col8" >loc_total </th>
#       <th id="T_eb17e_level0_col9" class="col_heading level0 col9" >loc_mean_file       </th>
#       <th id="T_eb17e_level0_col10" class="col_heading level0 col10" >loc_median_file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb17e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb17e_row0_col0" class="data row0 col0" >DAI          </td>
#       <td id="T_eb17e_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_eb17e_row0_col2" class="data row0 col2" >125</td>
#       <td id="T_eb17e_row0_col3" class="data row0 col3" >715</td>
#       <td id="T_eb17e_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_eb17e_row0_col5" class="data row0 col5" >1148</td>
#       <td id="T_eb17e_row0_col6" class="data row0 col6" >1.605594</td>
#       <td id="T_eb17e_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_eb17e_row0_col8" class="data row0 col8" >4851</td>
#       <td id="T_eb17e_row0_col9" class="data row0 col9" >156.483871</td>
#       <td id="T_eb17e_row0_col10" class="data row0 col10" >135.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eb17e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb17e_row1_col0" class="data row1 col0" >AAVE         </td>
#       <td id="T_eb17e_row1_col1" class="data row1 col1" >94</td>
#       <td id="T_eb17e_row1_col2" class="data row1 col2" >802</td>
#       <td id="T_eb17e_row1_col3" class="data row1 col3" >8950</td>
#       <td id="T_eb17e_row1_col4" class="data row1 col4" >38</td>
#       <td id="T_eb17e_row1_col5" class="data row1 col5" >14779</td>
#       <td id="T_eb17e_row1_col6" class="data row1 col6" >1.651285</td>
#       <td id="T_eb17e_row1_col7" class="data row1 col7" >2.000000</td>
#       <td id="T_eb1

# %% [markdown]
# # Explore sample project

# %%
from config import project_configs
from Project import Project

tether = next(pc for pc in project_configs if pc.name == 'USD Tether')
p_tether = Project(tether)

for s in p_tether:
  print(s.contracts)
# Out:
# INFO:Project:Cloning repo https://github.com/tethercoin/USDT
# INFO:Project:USDT cloned with submodules.
# INFO:solc_select_api:solc version set to 0.4.17
# [<slither.core.declarations.contract.Contract object at 0x173ec56f0>, <slither.core.declarations.contract.Contract object at 0x173ec5690>, <slither.core.declarations.contract.Contract object at 0x173ec57e0>, <slither.core.declarations.contract.Contract object at 0x173ec55d0>, <slither.core.declarations.contract.Contract object at 0x173ec57b0>, <slither.core.declarations.contract.Contract object at 0x173ec5930>, <slither.core.declarations.contract.Contract object at 0x173ec5630>, <slither.core.declarations.contract.Contract object at 0x173ec59f0>, <slither.core.declarations.contract.Contract object at 0x173ec5a80>, <slither.core.declarations.contract.Contract object at 0x173ec5b10>]

# %%
s.contracts[5].is_c
# Out:
# False
